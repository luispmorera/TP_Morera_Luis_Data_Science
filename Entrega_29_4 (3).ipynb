# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
url = 'https://raw.githubusercontent.com/luispmorera/CoderHouse01/main/Stats%20survey.csv'
df = pd.read_csv(url)
df
# Out:
#                       Timestamp Your Sex?  \
# 0     2024/03/07 5:12:01 pm EET    Female
# 1     2024/03/07 5:12:08 pm EET      Male
# 2     2024/03/07 5:12:25 pm EET      Male
# 3     2024/03/07 5:12:28 pm EET      Male
# 4     2024/03/07 5:13:00 pm EET    Female
# ..                          ...       ...
# 401  2024/03/12 11:05:33 am EET    Female
# 402   2024/03/12 3:26:14 pm EET    Female
# 403  2024/03/13 10:32:19 pm EET    Female
# 404  2024/03/13 10:32:27 pm EET      Male
# 405  2024/03/16 10:30:36 pm EET    Female
#
#      Your Matric (grade 12) Average/ GPA (in %)  \
# 0                                          76.0
# 1                                          89.0
# 2                                          76.0
# 3                                          89.0
# 4                                          74.0
# ..                                          ...
# 401                                        74.0
# 402                                        73.0
# 403                                        86.0
# 404                                        85.0
# 405                                        80.0
#
#     What year were you in last year (2023) ?  \
# 0                                   2nd Year
# 1                                   2nd Year
# 2                                   1st Year
# 3                                   2nd Year
# 4                                   2nd Year
# ..                                       ...
# 401                                      NaN
# 402                                 2nd Year
# 403                                 1st Year
# 404                                      NaN
# 405                                 1st Year
#
#     What faculty does your degree fall under?  \
# 0                      Arts & Social Sciences
# 1              Economic & Management Sciences
# 2                                AgriSciences
# 3                                 Engineering
# 4                      Arts & Social Sciences
# ..                                        ...
# 401                                   Science
# 402            Economic & Management Sciences
# 403                                       NaN
# 404            Economic & Management Sciences
# 405                                       NaN
#
#      Your 2023 academic year average/GPA in % (Ignore if you are 2024 1st year student)  \
# 0                                                 72.0
# 1                                                 75.0
# 2                                                 55.0
# 3                                                 84.0
# 4                                                 52.0
# ..                                                 ...
# 401                                                NaN
# 402                                               58.0
# 403                                                NaN
# 404                                                NaN
# 405                                               63.0
#
#           Your Accommodation Status Last Year (2023)  \
# 0    Private accommodation/ stay with family/friends
# 1    Private accommodation/ stay with family/friends
# 2    Private accommodation/ stay with family/friends
# 3    Private accommodation/ stay with family/friends
# 4    Private accommodation/ stay with family/friends
# ..                                               ...
# 401  Private accommodation/ stay with family/friends
# 402  Private accommodation/ stay with family/friends
# 403  Private accommodation/ stay with family/friends
# 404  Private accommodation/ stay with family/friends
# 405  Private accommodation/ stay with family/friends
#
#     Monthly Allowance in 2023 Were you on scholarship/bursary in 2023?  \
# 0              R 4001- R 5000                                       No
# 1             R 7001 - R 8000                      Yes (NSFAS, etc...)
# 2              R 4001- R 5000                                       No
# 3             R 6001 - R 7000                                       No
# 4              R 4001- R 5000                                       No
# ..                        ...                                      ...
# 401                       NaN                                       No
# 402           R 6001 - R 7000                      Yes (NSFAS, etc...)
# 403            R 4001- R 5000                                       No
# 404            R 4001- R 5000                                       No
# 405           R 5001 - R 6000                                       No
#
#     Additional amount of studying (in hrs) per week  \
# 0                                                8+
# 1                                                8+
# 2                                               3-5
# 3                                               3-5
# 4                                               3-5
# ..                                              ...
# 401                                             3-5
# 402                                             5-8
# 403                                             5-8
# 404                                             1-3
# 405                                             3-5
#
#     How often do you go out partying/socialising during the week?   \
# 0                                        Only weekends
# 1                                        Only weekends
# 2                                                    2
# 3                                                    3
# 4                                        Only weekends
# ..                                                 ...
# 401                                                  3
# 402                                                  1
# 403                                                  2
# 404                                                 4+
# 405                                      Only weekends
#
#     On a night out, how many alcoholic drinks do you consume?  \
# 0                                                   8+
# 1                                                  3-5
# 2                                                   8+
# 3                                                   8+
# 4                                                  5-8
# ..                                                 ...
# 401                                                1-3
# 402                                                 8+
# 403                                                3-5
# 404                                                5-8
# 405                                                3-5
#
#     How many classes do you miss per week due to alcohol reasons, (i.e: being hungover or too tired?)  \
# 0                                                    3
# 1                                                   4+
# 2                                                    3
# 3                                                    2
# 4                                                    1
# ..                                                 ...
# 401                                                  0
# 402                                                  0
# 403                                                  1
# 404                                                 4+
# 405                                                  1
#
#     How many modules have you failed thus far into your studies?  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    3
# ..                                                 ...
# 401                                                  0
# 402                                                  0
# 403                                                  0
# 404                                                  0
# 405                                                  0
#
#     Are you currently in a romantic relationship?  \
# 0                                             Yes
# 1                                              No
# 2                                              No
# 3                                             Yes
# 4                                              No
# ..                                            ...
# 401                                            No
# 402                                           Yes
# 403                                            No
# 404                                            No
# 405                                            No
#
#     Do your parents approve alcohol consumption?  \
# 0                                            Yes
# 1                                            Yes
# 2                                            Yes
# 3                                            Yes
# 4                                            Yes
# ..                                           ...
# 401                                          Yes
# 402                                          Yes
# 403                                          Yes
# 404                                          Yes
# 405                                           No
#
#     How strong is your relationship with your parent/s?
# 0                                           Very close
# 1                                           Very close
# 2                                           Very close
# 3                                           Very close
# 4                                                 Fair
# ..                                                 ...
# 401                                              Close
# 402                                         Very close
# 403                                         Very close
# 404                                              Close
# 405                                              Close
#
# [406 rows x 17 columns]

# %%
#LA BASE DE DATOS CONSISTE EN UNA ENCUESTA A ESTUDIANTES SOBRE SU CONSUMO DE ALCOHOL Y OTRAS VARIABLES DEMOGRÁFICAS.
#LA HIPOTESIS CONSISTE EN EVALUAR SI EL CONSUMO DEL ALCOHOL AFEFCTA EL RENIDMIENTO ACADÉMICO. LA CONFIRMACIÓN O DESCARTE DE LA
#HIPOTESIS SE REALIZARÁ A TRAVÉS DE CORRELACIONES BIVARIADAS Y REGRESIONES LINEALES EN UNA SEGUNDA ETAPA DEL PROYECTO
#EN ESTA PRIMERA ETAPA SE REALIZARÁN GRÁFICOS DESCRIPTIVOS EXPLORATIVOS DE LA BASE.

# %%
from IPython.display import Image, display

url = "https://www.googleapis.com/download/storage/v1/b/kaggle-user-content/o/inbox%2F19333363%2F0343dcc8ef6a299793ac9c2ac765346c%2Fbeg.jpg?generation=1711370517515575&alt=media"

display(Image(url=url))
# Out:
# <img src="https://www.googleapis.com/download/storage/v1/b/kaggle-user-content/o/inbox%2F19333363%2F0343dcc8ef6a299793ac9c2ac765346c%2Fbeg.jpg?generation=1711370517515575&alt=media"/>

# %%
df.columns
# Out:
# Index(['Timestamp', 'Your Sex?', 'Your Matric (grade 12) Average/ GPA (in %)',
#        'What year were you in last year (2023) ?',
#        'What faculty does your degree fall under?',
#        'Your 2023 academic year average/GPA in % (Ignore if you are 2024 1st year student)',
#        'Your Accommodation Status Last Year (2023)',
#        'Monthly Allowance in 2023', 'Were you on scholarship/bursary in 2023?',
#        'Additional amount of studying (in hrs) per week',
#        'How often do you go out partying/socialising during the week? ',
#        'On a night out, how many alcoholic drinks do you consume?',
#        'How many classes do you miss per week due to alcohol reasons, (i.e: being hungover or too tired?)',
#        'How many modules have you failed thus far into your studies?',
#        'Are you currently in a romantic relationship?',
#        'Do your parents approve alcohol consumption?',
#        'How strong is your relationship with your parent/s?'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 406 entries, 0 to 405
# Data columns (total 17 columns):
#  #   Column                                                                                             Non-Null Count  Dtype
# ---  ------                                                                                             --------------  -----
#  0   Timestamp                                                                                          406 non-null    object
#  1   Your Sex?                                                                                          404 non-null    object
#  2   Your Matric (grade 12) Average/ GPA (in %)                                                         399 non-null    float64
#  3   What year were you in last year (2023) ?                                                           333 non-null    object
#  4   What faculty does your degree fall under?                                                          399 non-null    object
#  5   Your 2023 academic year average/GPA in % (Ignore if you are 2024 1st year student)                 320 non-null    float64
#  6   Your Accommodation Status Last Year (2023)                                                         383 non-null    object
#  7   Monthly Allowance in 2023                                                                          375 non-null    object
#  8   Were you on scholarship/bursary in 2023?                                                           398 non-null    object
#  9   Additional amount of studying (in hrs) per week                                                    403 non-null    object
#  10  How often do you go out partying/socialising during the week?                                      404 non-null    object
#  11  On a night out, how many alcoholic drinks do you consume?                                          404 non-null    object
#  12  How many classes do you miss per week due to alcohol reasons, (i.e: being hungover or too tired?)  403 non-null    object
#  13  How many modules have you failed thus far into your studies?                                       403 non-null    object
#  14  Are you currently in a romantic relationship?                                                      403 non-null    object
#  15  Do your parents approve alcohol consumption?                                                       402 non-null    object
#  16  How strong is your relationship with your parent/s?                                                403 non-null    object
# dtypes: float64(2), object(15)
# memory usage: 54.0+ KB

# %%
df.shape
# Out:
# (406, 17)

# %%
df.isna().sum()
# Out:
# Timestamp                                                                                             0
# Your Sex?                                                                                             2
# Your Matric (grade 12) Average/ GPA (in %)                                                            7
# What year were you in last year (2023) ?                                                             73
# What faculty does your degree fall under?                                                             7
# Your 2023 academic year average/GPA in % (Ignore if you are 2024 1st year student)                   86
# Your Accommodation Status Last Year (2023)                                                           23
# Monthly Allowance in 2023                                                                            31
# Were you on scholarship/bursary in 2023?                                                              8
# Additional amount of studying (in hrs) per week                                                       3
# How often do you go out partying/socialising during the week?                                         2
# On a night out, how many alcoholic drinks do you consume?                                             2
# How many classes do you miss per week due to alcohol reasons, (i.e: being hungover or too tired?)     3
# How many modules have you failed thus far into your studies?                                          3
# Are you currently in a romantic relationship?                                                         3
# Do your parents approve alcohol consumption?                                                          4
# How strong is your relationship with your parent/s?                                                   3
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.heatmap(df.isna(), cbar=False, yticklabels=False, cmap='viridis')
plt.title('Mapa de calor de valores faltantes')
plt.show()

# %%
df.describe()
# Out:
#        Your Matric (grade 12) Average/ GPA (in %)  \
# count                                  399.000000
# mean                                    77.989724
# std                                      7.048618
# min                                     34.000000
# 25%                                     74.000000
# 50%                                     78.000000
# 75%                                     83.000000
# max                                     99.000000
#
#        Your 2023 academic year average/GPA in % (Ignore if you are 2024 1st year student)
# count                                         320.000000
# mean                                           66.268469
# std                                             9.147906
# min                                            30.000000
# 25%                                            60.000000
# 50%                                            65.000000
# 75%                                            73.000000
# max                                            95.220000

# %%
df['Your Sex?'] = df['Your Sex?'].astype('category')
df['What year were you in last year (2023) ?'] = df['What year were you in last year (2023) ?'].astype('category')
df['How many classes do you miss per week due to alcohol reasons, (i.e: being hungover or too tired?)'] = df['How many classes do you miss per week due to alcohol reasons, (i.e: being hungover or too tired?)'].astype('category')
df['Monthly Allowance in 2023'] = df['Monthly Allowance in 2023'].astype('category')
df['Your 2023 academic year average/GPA in % (Ignore if you are 2024 1st year student)'] = df['Your 2023 academic year average/GPA in % (Ignore if you are 2024 1st year student)'].astype('float64')

# %%
descripcion_categoricas = df.describe(include=['category'])
descripcion_categoricas
# Out:
#        Your Sex? What year were you in last year (2023) ?  \
# count        404                                      333
# unique         2                                        5
# top         Male                                 2nd Year
# freq         216                                      153
#
#        Monthly Allowance in 2023  \
# count                        375
# unique                         5
# top               R 4001- R 5000
# freq                         159
#
#        How many classes do you miss per week due to alcohol reasons, (i.e: being hungover or too tired?)
# count                                                 403
# unique                                                  5
# top                                                     0
# freq                                                  214

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 406 entries, 0 to 405
# Data columns (total 17 columns):
#  #   Column                                                                                             Non-Null Count  Dtype
# ---  ------                                                                                             --------------  -----
#  0   Timestamp                                                                                          406 non-null    object
#  1   Your Sex?                                                                                          404 non-null    category
#  2   Your Matric (grade 12) Average/ GPA (in %)                                                         399 non-null    float64
#  3   What year were you in last year (2023) ?                                                           333 non-null    category
#  4   What faculty does your degree fall under?                                                          399 non-null    object
#  5   Your 2023 academic year average/GPA in % (Ignore if you are 2024 1st year student)                 320 non-null    float64
#  6   Your Accommodation Status Last Year (2023)                                                         383 non-null    object
#  7   Monthly Allowance in 2023                                                                          375 non-null    category
#  8   Were you on scholarship/bursary in 2023?                                                           398 non-null    object
#  9   Additional amount of studying (in hrs) per week                                                    403 non-null    object
#  10  How often do you go out partying/socialising during the week?                                      404 non-null    object
#  11  On a night out, how many alcoholic drinks do you consume?                                          404 non-null    object
#  12  How many classes do you miss per week due to alcohol reasons, (i.e: being hungover or too tired?)  403 non-null    category
#  13  How many modules have you failed thus far into your studies?                                       403 non-null    object
#  14  Are you currently in a romantic relationship?                                                      403 non-null    object
#  15  Do your parents approve alcohol consumption?                                                       402 non-null    object
#  16  How strong is your relationship with your parent/s?                                                403 non-null    object
# dtypes: category(4), float64(2), object(11)
# memory usage: 43.7+ KB

# %%
from matplotlib import pyplot as plt
import seaborn as sns
df.groupby('What year were you in last year (2023) ?').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)
plt.title('Cantidad de estudiantes por año de cursada')
# Out:
# Text(0.5, 1.0, 'Cantidad de estudiantes por año de cursada')

# %%
sns.countplot(y='What year were you in last year (2023) ?', data=df, palette='Dark2')
plt.title('Cantidad de estudiantes por año de cursada')
plt.show()
# Out:
# <ipython-input-120-e06c037bc8b5>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y='What year were you in last year (2023) ?', data=df, palette='Dark2')

# %%
from matplotlib import pyplot as plt
import seaborn as sns
df.groupby('How many classes do you miss per week due to alcohol reasons, (i.e: being hungover or too tired?)').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)
plt.title('Cantidad de clases perdidas por consumo de alcohol')
# Out:
# Text(0.5, 1.0, 'Cantidad de clases perdidas por consumo de alcohol')

# %%
sns.countplot(y = 'How many classes do you miss per week due to alcohol reasons, (i.e: being hungover or too tired?)', data = df, palette = 'tab10')
plt.title('Cantidad de clases perdidas por consumo de alcohol')
# Out:
# <ipython-input-122-6229f3293459>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y = 'How many classes do you miss per week due to alcohol reasons, (i.e: being hungover or too tired?)', data = df, palette = 'tab10')
# Text(0.5, 1.0, 'Cantidad de clases perdidas por consumo de alcohol')

# %%
from matplotlib import pyplot as plt
import seaborn as sns
df.groupby('Your Sex?').size().plot(kind='pie', colors=sns.color_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
datos_agrupados = df.groupby('Your Sex?').size()
plt.pie(datos_agrupados, labels=datos_agrupados.index, autopct='%1.1f%%', colors=sns.color_palette('tab20'))
plt.title('Distribución de sexo')
# Out:
# Text(0.5, 1.0, 'Distribución de sexo')

# %%
from matplotlib import pyplot as plt
import seaborn as sns
df.groupby('Monthly Allowance in 2023').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)
plt.title('Mensualidad')
# Out:
# Text(0.5, 1.0, 'Mensualidad')

# %%
#gráfico usando seaborn
sns.countplot(y='Monthly Allowance in 2023', data=df, palette='Dark2')
plt.title('Mensualidad')
plt.show()
# Out:
# <ipython-input-126-220358ee39e7>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y='Monthly Allowance in 2023', data=df, palette='Dark2')

# %%
from matplotlib import pyplot as plt
df['Your 2023 academic year average/GPA in % (Ignore if you are 2024 1st year student)'].plot(kind='hist', bins=20, title='Your 2023 academic year average/GPA in % (Ignore if you are 2024 1st year student)')
plt.gca().spines[['top', 'right',]].set_visible(False)
plt.title('Distribución de acuerdo al GPA')
# Out:
# Text(0.5, 1.0, 'Distribución de acuerdo al GPA')

# %%
sns.histplot(data=df, x='Your 2023 academic year average/GPA in % (Ignore if you are 2024 1st year student)', bins=20)
plt.title('Your 2023 academic year average/GPA in % (Ignore if you are 2024 1st year student)')
plt.show()

# %%
from matplotlib import pyplot as plt
df['Your Matric (grade 12) Average/ GPA (in %)'].plot(kind='hist', bins=20, title='Your Matric (grade 12) Average/ GPA (in %)')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
sns.histplot(data=df, x='Your Matric (grade 12) Average/ GPA (in %)', bins=20)
plt.title('Your Matric (grade 12) Average/ GPA (in %)')
plt.show()

# %%
promedio_por_genero = df.groupby('Your Sex?')['Your 2023 academic year average/GPA in % (Ignore if you are 2024 1st year student)'].mean()
promedio_por_genero = promedio_por_genero.reset_index()
sns.barplot(x='Your Sex?', y='Your 2023 academic year average/GPA in % (Ignore if you are 2024 1st year student)', data=promedio_por_genero)
plt.title('GPA por género')
plt.show()

# %%
df['On a night out, how many alcoholic drinks do you consume?'] = df['On a night out, how many alcoholic drinks do you consume?'].astype('category')

# %%
sns.histplot(data =df, x ='On a night out, how many alcoholic drinks do you consume?', y = 'Your Sex?')
# Out:
# <Axes: xlabel='On a night out, how many alcoholic drinks do you consume?', ylabel='Your Sex?'>

# %%
sns.scatterplot(data =df, x ='On a night out, how many alcoholic drinks do you consume?', y = 'Your Matric (grade 12) Average/ GPA (in %)')
# Out:
# <Axes: xlabel='On a night out, how many alcoholic drinks do you consume?', ylabel='Your Matric (grade 12) Average/ GPA (in %)'>
